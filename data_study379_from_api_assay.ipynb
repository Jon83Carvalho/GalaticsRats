# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json as js

# %%
file_path='dados/assays_379.json'

# %%
with open(file_path, 'r') as file:
    data_379_assay = js.load(file)

# %%
df_379_assay=pd.DataFrame(data_379_assay)

# %%
df_379_assay['tableData'][['current']][0]
# Out:
# [{'index': 0,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI1',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '4.9',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI1',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '312',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI1_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI1_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI1_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI1_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '3.78',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '54477267',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 1,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI2',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '5.6',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI2',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '339',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '10-Feb-21',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI2_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI2_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI2_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI2_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '3.02',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '61115053',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 2,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI3',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '6.6',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI3',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '332',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI3_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI3_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI3_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI3_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '1.53',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '63712483',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 3,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI4',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '5.5',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI4',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '346',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '29-Oct-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI4_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI4_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI4_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI4_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '0.6',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '63108146',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 4,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI5',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '5.7',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI5',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '313',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI5_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI5_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI5_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI5_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '1.86',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '56208952',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 5,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI6',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '5.7',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI6',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '335',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '10-Feb-21',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI6_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI6_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI6_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI6_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '4',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '61969509',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 6,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI7',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '4.7',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI7',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '323',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '17-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI7_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI7_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI7_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI7_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '1.88',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '63099811',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 7,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI8',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '6',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI8',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '316',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '17-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI8_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI8_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI8_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI8_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '3.95',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '82765564',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 8,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_OLD_BI9',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '5.1',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_OLD_BI9',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '320',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '29-Oct-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI9_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI9_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI9_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_OLD_BI9_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '2.5',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '60838427',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 9,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_YNG_BI11',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '4.7',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_YNG_BI11',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '338',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI11_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI11_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI11_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI11_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '4.08',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '62381689',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 10,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_YNG_BI12',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '5.2',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_YNG_BI12',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '350',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '10-Feb-21',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI12_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI12_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI12_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI12_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '2.75',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '57800093',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 11,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_YNG_BI13',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '6.1',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_YNG_BI13',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '334',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI13_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI13_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI13_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI13_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '1.24',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '61620904',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 12,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_YNG_BI14',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '6.5',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_YNG_BI14',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '379',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Feb-21',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI14_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI14_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI14_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI14_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '5.85',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '70028229',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 13,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_YNG_BI15',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '5.5',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_YNG_BI15',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '350',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '10-Feb-21',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI15_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI15_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI15_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI15_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '1.45',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '58206630',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 14,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_YNG_BI16',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '4.6',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_YNG_BI16',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '321',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '14-Dec-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI16_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI16_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI16_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI16_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '1.49',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '57816247',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 15,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_YNG_BI17',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA ScreenTape Assay',
#   'Parameter Value[QA Score]': '7.6',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_ISS-T_YNG_BI17',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 1',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '336',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI17_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI17_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI17_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_ISS-T_YNG_BI17_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '2.89',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '65983709',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 16,
#   'Sample Name': 'RR8_LVR_BSL_ISS-T_YNG_BI18',
#   'Protocol REF': 'nucleic acid extraction',
# ...
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '1.35',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '59557018',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 20,
#   'Sample Name': 'RR8_LVR_BSL_LAR_YNG_BL2',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA 6000 Nano Assay',
#   'Parameter Value[QA Score]': '9.9',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_LAR_YNG_BL2',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 2',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '313',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '10-Feb-21',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL2_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL2_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL2_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL2_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '1.6',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '54003703',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 21,
#   'Sample Name': 'RR8_LVR_BSL_LAR_YNG_BL4',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA 6000 Nano Assay',
#   'Parameter Value[QA Score]': '9',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_LAR_YNG_BL4',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 2',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '312',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL4_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL4_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL4_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL4_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '0.83',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '56734921',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 22,
#   'Sample Name': 'RR8_LVR_BSL_LAR_YNG_BL5',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA 6000 Nano Assay',
#   'Parameter Value[QA Score]': '9.6',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_LAR_YNG_BL5',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 2',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '309',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL5_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL5_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL5_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL5_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '0.36',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '61343673',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 23,
#   'Sample Name': 'RR8_LVR_BSL_LAR_YNG_BL6',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA 6000 Nano Assay',
#   'Parameter Value[QA Score]': '9.2',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_LAR_YNG_BL6',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 2',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '396',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL6_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL6_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL6_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL6_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '0.8',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '60909317',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'},
#  {'index': 24,
#   'Sample Name': 'RR8_LVR_BSL_LAR_YNG_BL7',
#   'Protocol REF': 'nucleic acid extraction',
#   'Parameter Value[QA Instrument]': 'Agilent 4200 Tapestation',
#   'Parameter Value[QA Assay]': 'Agilent RNA 6000 Nano Assay',
#   'Parameter Value[QA Score]': '9.8',
#   'Unit': 'RNA Integrity Number',
#   'Term Source REF': 'NCIT',
#   'Term Accession Number': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C63637',
#   'Extract Name': 'RR8_LVR_BSL_LAR_YNG_BL7',
#   'Protocol REF.1': 'spike-in protocol',
#   'Parameter Value[Spike-in Quality Control]': 'ERCC ExFold RNA Spike-In Mix',
#   'Term Source REF.1': '',
#   'Term Accession Number.1': '',
#   'Parameter Value[Spike-in Mix Number]': 'Mix 2',
#   'Term Source REF.2': '',
#   'Term Accession Number.2': '',
#   'Protocol REF.2': 'library construction',
#   'Parameter Value[library selection]': 'Ribo-depletion',
#   'Parameter Value[library layout]': 'PAIRED',
#   'Parameter Value[stranded]': 'STRANDED',
#   'Parameter Value[Library QA Instrument]': 'Agilent 4200 TapeStation',
#   'Term Source REF.3': '',
#   'Term Accession Number.3': '',
#   'Parameter Value[Library QA Assay]': 'Agilent D1000 ScreenTape Assay',
#   'Term Source REF.4': '',
#   'Term Accession Number.4': '',
#   'Parameter Value[Fragment Size]': '309',
#   'Unit.1': 'base pair',
#   'Term Source REF.5': 'UO',
#   'Term Accession Number.5': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Comment[Library Prep Date]': '24-Nov-20',
#   'Protocol REF.3': 'nucleic acid sequencing',
#   'Parameter Value[sequencing instrument]': 'Illumina NovaSeq 6000',
#   'Parameter Value[Read Length]': '149',
#   'Unit.2': 'base pair',
#   'Term Source REF.6': 'UO',
#   'Term Accession Number.6': 'http://purl.obolibrary.org/obo/UO_0000244',
#   'Parameter Value[base caller]': 'bcl2fastq',
#   'Assay Name': 'rna-seq',
#   'Raw Data File': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL7_R1_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL7_R1_raw.fastq.gz</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL7_R2_raw.fastq.gz&version=1" target="_blank">GLDS-379_rna-seq_RR8_LVR_BSL_LAR_YNG_BL7_R2_raw.fastq.gz</a>',
#   'Protocol REF.4': 'GeneLab raw data processing protocol',
#   'Parameter Value[rRNA Contamination]': '3.52',
#   'Unit.3': 'percent',
#   'Term Source REF.7': 'UO',
#   'Term Accession Number.7': 'http://purl.obolibrary.org/obo/UO_0000187',
#   'Parameter Value[Read Depth]': '55178075',
#   'Unit.4': 'read',
#   'Term Source REF.8': 'SO',
#   'Term Accession Number.8': 'http://purl.obolibrary.org/obo/SO_0000150',
#   'Parameter Value[Raw sequence data/MultiQC Reports]': '<a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc.html&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc.html</a>, <a href="/geode-py/ws/studies/OSD-379/download?file=GLDS-379_rna_seq_raw_multiqc_data.zip&version=1" target="_blank">GLDS-379_rna_seq_raw_multiqc_data.zip</a>'}]

# %%
df_379_assay_table=pd.DataFrame(df_379_assay['tableData'][['current']][0],index=[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1701         blocks = _form_blocks(arrays, names, axes)
# -> 1702         mgr = BlockManager(blocks, axes)
#    1703         mgr._consolidate_inplace()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     322             if block.shape[1:] != mgr_shape[1:]:
# --> 323                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     324         if len(self.items) != tot_items:
#
# ValueError: Shape of passed values is (25, 51), indices imply (1, 51)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-5053b431c12c> in <module>
# ----> 1 df_379_assay_table=pd.DataFrame(df_379_assay['tableData'][['current']][0],index=[0])
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     580                             index = ibase.default_index(len(data))
#     581
# --> 582                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     583                 else:
#     584                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      93     axes = [columns, index]
#      94
# ---> 95     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      96
#      97
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1704         return mgr
#    1705     except ValueError as e:
# -> 1706         raise construction_error(len(arrays), arrays[0].shape, axes, e)
#    1707
#    1708
#
# ValueError: Shape of passed values is (25, 51), indices imply (1, 51)

# %%
df_379_assay_table
# Out:
#   tableData
# 0       NaN

# %%
df_379_assay_table.to_excel('data_379_assay_excel.xlsx', index=False, sheet_name='Sheet1')

# %%
# Split the "Parameter Value: QA Score" column and extract the numerical value
osd_379_assays['QA Score'] = osd_379_assays['Parameter Value: QA Score'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
osd_379_assays['QA Score']
# Out:
# 0      4.9
# 1      5.6
# 2      6.6
# 3      5.5
# 4      5.7
# 5      5.7
# 6      4.7
# 7      6.0
# 8      5.1
# 9      4.7
# 10     5.2
# 11     6.1
# 12     6.5
# 13     5.5
# 14     4.6
# 15     7.6
# 16     5.9
# 17     6.7
# 18     6.1
# 19    10.0
# 20     9.9
# 21     9.0
# 22     9.6
# 23     9.2
# 24     9.8
# Name: QA Score, dtype: float64

# %%
osd_379_assays.dtypes
# Out:
# Sample Name                                            object
# Protocol REF                                           object
# Parameter Value: QA Instrument                         object
# Parameter Value: QA Assay                              object
# Parameter Value: QA Score                              object
# Unit                                                   object
# Term Source REF                                        object
# Term Accession Number                                  object
# Extract Name                                           object
# Protocol REF.1                                         object
# Parameter Value: Spike-in Quality Control              object
# Term Source REF.1                                     float64
# Term Accession Number.1                               float64
# Parameter Value: Spike-in Mix Number                   object
# Term Source REF.2                                     float64
# Term Accession Number.2                               float64
# Protocol REF.2                                         object
# Parameter Value: library selection                     object
# Parameter Value: library layout                        object
# Parameter Value: stranded                              object
# Parameter Value: Library QA Instrument                 object
# Term Source REF.3                                     float64
# Term Accession Number.3                               float64
# Parameter Value: Library QA Assay                      object
# Term Source REF.4                                     float64
# Term Accession Number.4                               float64
# Parameter Value: Fragment Size                         object
# Unit.1                                                 object
# Term Source REF.5                                      object
# Term Accession Number.5                                object
# Comment: Library Prep Date                             object
# Protocol REF.3                                         object
# Parameter Value: sequencing instrument                 object
# Parameter Value: Read Length                           object
# Unit.2                                                 object
# Term Source REF.6                                      object
# Term Accession Number.6                                object
# Parameter Value: base caller                           object
# Assay Name                                             object
# Raw Data File                                          object
# Protocol REF.4                                         object
# Parameter Value: rRNA Contamination                    object
# Unit.3                                                 object
# Term Source REF.7                                      object
# Term Accession Number.7                                object
# Parameter Value: Read Depth                            object
# Unit.4                                                 object
# Term Source REF.8                                      object
# Term Accession Number.8                                object
# Parameter Value: Raw sequence data/MultiQC Reports     object
# dtype: object

# %%
# Create a histogram using seaborn
plt.figure(figsize=(10, 6))
ax = sns.histplot(osd_379_assays['QA Score'], kde=True)

# Annotate each bar with its height
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.0f}', 
                xy=(p.get_x() + p.get_width() / 2, height), 
                xytext=(0, 5),  # 5 points vertical offset
                textcoords='offset points', 
                ha='center', va='bottom')

plt.title('Distribution of QA Score')
plt.xlabel('QA Score')
plt.ylabel('Frequency')
plt.show()

# %%
len(osd_379_assays['QA Score'])
# Out:
# 25

# %%
# Example visualization: Distribution of a column in OSD-379 assays
plt.figure(figsize=(10, 6))
sns.histplot(osd_379_assays['column_name'], kde=True)
plt.title('Distribution of Column Name in OSD-379 Assays')
plt.xlabel('Column Name')
plt.ylabel('Frequency')
plt.show()

# Example visualization: Scatter plot between two columns in OSD-665 samples
plt.figure(figsize=(10, 6))
sns.scatterplot(x='column_x', y='column_y', data=osd_665_samples)
plt.title('Scatter Plot between Column X and Column Y in OSD-665 Samples')
plt.xlabel('Column X')
plt.ylabel('Column Y')
plt.show()
